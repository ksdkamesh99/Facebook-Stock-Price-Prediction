# %%
cd /content/drive/My Drive/Facebook Stock Price Prediction
# Out:
# /content/drive/My Drive/Facebook Stock Price Prediction

# %% [markdown]
# # Installing Pandas Data Reader

# %%
# !pip install pandas_datareader

# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr

# %% [markdown]
# # Getting Data From Tiingo

# %% [markdown]
# ## API Key
#
# The API Key will be getting from https://api.tiingo.com/documentation/general/overview .

# %%
API_KEY=input("Enter the API Key ")
# Out:
# Enter the API Key 4fc2b08a48b1a3336d28e92bbaa982882844855b

# %% [markdown]
# ## Getting Facebook Stocks

# %%
data=pdr.get_data_tiingo('FB',api_key=API_KEY)

# %%
data.head()
# Out:
#                                   close   high  ...  divCash  splitFactor
# symbol date                                     ...
# FB     2015-10-08 00:00:00+00:00  92.47  93.22  ...      0.0          1.0
#        2015-10-09 00:00:00+00:00  93.24  93.74  ...      0.0          1.0
#        2015-10-12 00:00:00+00:00  94.26  94.60  ...      0.0          1.0
#        2015-10-13 00:00:00+00:00  94.12  95.37  ...      0.0          1.0
#        2015-10-14 00:00:00+00:00  94.07  95.20  ...      0.0          1.0
#
# [5 rows x 12 columns]

# %%
data.tail()
# Out:
#                                    close     high  ...  divCash  splitFactor
# symbol date                                        ...
# FB     2020-09-29 00:00:00+00:00  261.79  263.330  ...      0.0          1.0
#        2020-09-30 00:00:00+00:00  261.90  266.085  ...      0.0          1.0
#        2020-10-01 00:00:00+00:00  266.63  268.330  ...      0.0          1.0
#        2020-10-02 00:00:00+00:00  259.94  265.150  ...      0.0          1.0
#        2020-10-05 00:00:00+00:00  264.65  264.865  ...      0.0          1.0
#
# [5 rows x 12 columns]

# %%
data.to_csv('facebook_data.csv',index=False)

# %% [markdown]
# # Load from CSV

# %%
data=pd.read_csv('facebook_data.csv')

# %%
data.shape
# Out:
# (1257, 12)
